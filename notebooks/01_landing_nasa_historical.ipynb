# %%
#ingesta historico de incendios de 7 dias (nasa firms) a la capa landing
from tfm_mobility.ingesters.nasa_ingester import NASAIngester

print("Consultando historico acumulado de NASA")
nasa_batch_file_path = NASAIngester().fetch_batch_to_landing()

#se valida el resultado de la ingesta para notificar al orquestador de fabric
if nasa_batch_file_path:
    print(f"Historico NASA guardado en: {nasa_batch_file_path}")
    mssparkutils.notebook.exit(nasa_batch_file_path)
else:
    raise Exception("Fallo en la ingesta de NASA Historico")
