# %%
#Ingesta histórico de incendios de 7 días (NASA FIRMS) a Landing

from tfm_mobility.ingesters.nasa_ingester import NASAIngester

print("[BATCH INGESTION] Consultando histórico acumulado de NASA FIRMS (7 días)...")
nasa_batch_file_path = NASAIngester().fetch_batch_to_landing()

if nasa_batch_file_path:
    print(f"[OK] Histórico NASA guardado en: {nasa_batch_file_path}")
    mssparkutils.notebook.exit(nasa_batch_file_path)
else:
    raise Exception("Fallo en la ingesta de NASA Histórico.")
