# %%
#Sincroniza Parquet RAW Batch (NASA Histórico, OSM Redes, OSM Lugares) a Tablas Delta
from tfm_mobility.processors.bronze_processor import BronzeProcessor

print("Iniciando promoción de fuentes Batch a Tablas Delta")

#instancio el procesador bronze pasando la sesion activa de spark
processor = BronzeProcessor(spark)

#he ejecutado la promocion batch para actualizar las tablas delta correspondientes
processor.promote_batch_to_bronze()

print("Proceso finalizado. Tablas 'bronze_nasa_historical', 'bronze_osm_roads' y 'bronze_osm_places' actualizadas.")
