# %%
# ==============================================================================
# NOTEBOOK: 03_bronze_batch
# DESCRIPCIÓN: Sincroniza Parquet RAW Batch (NASA Histórico, OSM Redes, OSM Lugares) a Tablas Delta
# ==============================================================================
from tfm_mobility.processors.bronze_processor import BronzeProcessor

print("📦 [BRONZE BATCH] Iniciando promoción de fuentes Batch a Tablas Delta...")

# Instanciamos el procesador con la versión 0.7.4
processor = BronzeProcessor(spark)

# Ejecutamos la promoción exclusiva de Batch
processor.promote_batch_to_bronze()

print("✅ [BRONZE BATCH OK] Proceso finalizado. Tablas 'bronze_nasa_historical', 'bronze_osm_roads' y 'bronze_osm_places' actualizadas.")
