# %%
# ==============================================================================
# NOTEBOOK: 01_landing_weather
# ==============================================================================
from datetime import datetime
from tfm_mobility.ingesters.realtime.weather_ingester import WeatherIngester

timestamp_str = datetime.now().strftime("%Y%m%d_%H%M%S")

ingester = WeatherIngester()
saved_path = ingester.run(timestamp_str)

mssparkutils.notebook.exit(saved_path)
# Out:
# StatementMeta(, b49cfb37-b1b8-4ecf-8e13-ee761aa2b5cf, 5, Finished, Available, Finished, False)
# 2026-09-02 15:04:42,085 - INFO - 🌐 Iniciando descarga meteorológica para 12280 puntos a resolución ~10km...
# 2026-09-02 15:04:42,086 - INFO -  └─ Procesando lote 1/31 (400 puntos)...
# 2026-09-02 15:04:43,287 - INFO -  └─ Procesando lote 2/31 (400 puntos)...
# 2026-09-02 15:04:44,398 - INFO -  └─ Procesando lote 3/31 (400 puntos)...
# ...

# %%
# %%sql
# DROP TABLE IF EXISTS bronze_weather;
# DROP TABLE IF EXISTS silver_weather;
# Out:
# StatementMeta(, b49cfb37-b1b8-4ecf-8e13-ee761aa2b5cf, 7, Finished, Available, Finished, True)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
