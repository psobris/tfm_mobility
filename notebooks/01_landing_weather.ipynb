# %%
#ingesta meteorologica nrt a la capa landing mediante la api de open-meteo
from tfm_mobility.ingesters.realtime.weather_ingester import WeatherIngester

#instancio el ingestador meteorologico y ejecuto la descarga de la malla nacional
ingester = WeatherIngester()
saved_file = ingester.run()

print(f"Ingesta finalizada correctamente: {saved_file}")
